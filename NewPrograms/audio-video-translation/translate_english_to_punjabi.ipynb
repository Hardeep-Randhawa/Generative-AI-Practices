# %%
# !pip install deep-translator -quite
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.7 MB/s eta 0:00:00
# ...

# %%
from deep_translator import GoogleTranslator

english_text = """
Hello admin.
Welcome to the world of Artificial Intelligence.
I hope you enjoy learning Python and Gen AI courses.
"""

punjabi_text = GoogleTranslator(
    source='en',
    target='pa'
).translate(english_text)

print("Punjabi Translation:\n")
print(punjabi_text)
# Out:
# Punjabi Translation:
#
# ਹੈਲੋ ਐਡਮਿਨ.
# ਆਰਟੀਫੀਸ਼ੀਅਲ ਇੰਟੈਲੀਜੈਂਸ ਦੀ ਦੁਨੀਆ ਵਿੱਚ ਤੁਹਾਡਾ ਸੁਆਗਤ ਹੈ।
# ਮੈਨੂੰ ਉਮੀਦ ਹੈ ਕਿ ਤੁਸੀਂ Python ਅਤੇ Gen AI ਕੋਰਸ ਸਿੱਖਣ ਦਾ ਆਨੰਦ ਮਾਣੋਗੇ।
